# %% [markdown]
# # Chapter 4 — Geocentric Models

# %%
import numpy as np

# %%
# Code 4.1
num_replicates = 1000
num_uniforms = 16
lower_bound = -1
upper_bound = 1

pos = np.random.uniform(lower_bound, upper_bound, size=(num_replicates, num_uniforms)).sum(axis=1)

# %%
pos
# Out:
# array([-2.45930036e+00,  1.30683328e+00, -3.63062427e+00, -2.86302228e-01,
#        -6.72922647e-01, -1.67871349e-01, -3.09348555e+00,  5.02357364e-01,
#         9.80554507e-01,  1.92571510e-01,  1.61680875e+00,  4.69671767e-01,
#         2.81740581e+00,  1.06433888e-01,  3.15323251e+00,  2.30535818e+00,
#         1.47796572e+00, -3.62576739e+00,  4.01833973e+00,  1.98515984e+00,
#        -1.37383780e+00,  2.49488398e+00, -5.81583473e-01,  2.17265503e+00,
#        -3.58847419e+00,  2.81432559e+00, -3.41806698e+00,  3.87478332e+00,
#        -1.23242909e+00, -2.71103194e+00,  5.74381278e-01,  1.82993791e-02,
#        -3.46284090e+00, -8.92009374e-02, -4.13693252e-01, -2.32420362e+00,
#        -9.27970486e-01,  5.29058867e+00,  1.64328657e+00,  3.77122525e-01,
#         1.61993411e+00,  2.20939446e-01, -1.85246765e+00,  3.35047957e-02,
#        -1.97767612e+00, -1.04581126e+00, -8.68127032e-01,  1.43514431e+00,
# ...
